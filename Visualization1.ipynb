# %%
# %pylab inline
import matplotlib.pyplot as plt
import csv as csv
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
## opening and loading csv file
csv_file_object=csv.reader(open('train.csv','rb'))
header=csv_file_object.next()


## saving the file as an numpy array 
data=[]

for row in csv_file_object:
    data.append(row)
    
## turning the list object into an array object using numpy function
data=np.array(data).astype(np.int)

## Loading test data
csv_file_testobject=csv.reader(open('test.csv','rb'))
header=csv_file_testobject.next()

test=[]

for row in csv_file_testobject:
    test.append(row)

test=np.array(test).astype(np.int)

## Defining useful variables

X_train=data[0::,1::]
y_train=data[0::,0]
X_train=test

number_obs=np.size(data[0::,1])
pixel_height=28
pixel_width=28

# %%
images=X_train.reshape(len(y_train), pixel_height, pixel_width)
images.shape
# Out:
# (42000, 28, 28)

# %%
n_row, n_col=5,5

def print_digits(images, y, max_n=25):
    #set up the figure size in inches
    fig=plt.figure(figsize=(2.*n_col, 2*n_row))
    i=0
    while i<max_n and i<images.shape[0]:
        p=fig.add_subplot(n_row, n_col, i+1, xticks=[], yticks=[])
        p.imshow(images[i], cmap=plt.cm.bone, interpolation="nearest")
        i=i+1
print_digits(images, y_train, max_n=25)

# %%
## Visualizing classes via Principal Components

def plot_pca_scatter():
    colors=['black', 'blue', 'purple', 'yellow', 'white', 'red', 'lime', 'cyan', 'orange', 'gray']
    for i in xrange(len(colors)):
        px=X_pca[:,0][y_train==i]
        py=X_pca[:,1][y_train==i]
        plt.scatter(px,py, c=colors[i])
    
    plt.xlabel('First Principal Component')
    plt.ylabel('Second Principal Component')

# %%
from sklearn.decomposition import PCA
estimator=PCA(n_components=10)
X_pca=estimator.fit_transform(X_train)
plot_pca_scatter()

# %%
## let's try using 3 principal components with 3 dimensional scatter plot

from mpl_toolkits.mplot3d import Axes3D

def plot_pca_3dim_scatter():
    fig=plt.figure()
    ax=fig.add_subplot(111, projection='3d')
    
    colors=['black', 'blue', 'purple', 'yellow', 'white', 'red', 'lime', 'cyan', 'orange', 'gray']
    for i in xrange(len(colors)):
        px=X_pca[:,0][y_train==i]
        py=X_pca[:,1][y_train==i]
        pz=X_pca[:,2][y_train==i]
        ax.scatter(px, py, pz, zdir=u'z',s=20, depthshade=True, c=colors[i])
        
    plt.show()

# %%
plot_pca_3dim_scatter()
